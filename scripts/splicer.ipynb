# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from refnx.dataset import ReflectDataset

# %%
p = "H:DAV_Desktop/Users/! GraceC/Dec 2019/MnSi film/Reduced Data/"

# %%
d0 = ReflectDataset(p + "PLP0047208PolCorr.dat")
d1 = ReflectDataset(p + "PLP0047209PolCorr.dat")
d0 += d1 
d0.save(p + 'c_PLP0047208_PolCorr.dat')

# %%
fig, ax = d0.plot()
plt.yscale('log')
