# %%
import numpy as np
from refnx.reduce import PlatypusNexus, PlatypusReduce, ReductionOptions

# %%
options = ReductionOptions()
direct = PlatypusReduce('PLP0050634.nx.hdf', data_folder='U:\data\current')

# %%
output = direct.reduce('scratch.nx.hdf')[1]
output['omega']
# Out:
# D:\Users\platypus\.conda\envs\dev3\lib\site-packages\refnx\reduce\platypusnexus.py:1542: UserWarning: The foreground width ([81]) estimate does not match the divergence of the beam ([30.46684265]). Consider checking with manual beam finder.
#   warnings.warn(
# array([[0.6041845 , 0.60419177, 0.6041992 , 0.60420677, 0.60421449,
#         0.60422237, 0.60423041, 0.60423861, 0.60424698, 0.60425551,
#         0.60426422, 0.60427311, 0.60428217, 0.60429141, 0.60430085,
#         0.60431047, 0.60432029, 0.6043303 , 0.60434052, 0.60435094,
#         0.60436157, 0.60437242, 0.60438349, 0.60439478, 0.6044063 ,
#         0.60441805, 0.60443004, 0.60444227, 0.60445475, 0.60446748,
#         0.60448046, 0.60449371, 0.60450722, 0.60452101, 0.60453508,
#         0.60454943, 0.60456407, 0.604579  , 0.60459424, 0.60460978,
#         0.60462564, 0.60464182, 0.60465833, 0.60467516, 0.60469234,
#         0.60470986, 0.60472774, 0.60474598, 0.60476459, 0.60478357,
# ...
